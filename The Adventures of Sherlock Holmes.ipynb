# %%
Word Cloud-Sherlock Holmes

# %%
import os
import matplotlib.pyplot as plt
from wordcloud import WordCloud
# Out:
# /home/sita/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:281: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %%
os.chdir(r"/home/sita/Desktop")
text = open('sherlockholmes.txt', "r")

data=text.read()
data

# %matplotlib inline
plt.figure(figsize=(20,10))
wordcloud = WordCloud(background_color='white', mode = "RGB", width = 2000, height=1000).generate(data)
plt.suptitle("Sherlock Holmes Word Cloud", fontsize=50)
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
